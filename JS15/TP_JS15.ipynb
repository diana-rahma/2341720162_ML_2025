# %% [markdown]
# ### Tugas JS15

# %% [markdown]
# Deploy model dari PCVK studi kasus identifikasi metode pembuatan batik <br>
# Link HuggingFace: https://huggingface.co/spaces/dianarhmaw/identifikasi_batik
